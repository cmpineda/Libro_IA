# %% [markdown]
# # Capítulo 8: Introducción a las redes neuronales

# %% [markdown]
# ## Perceptrón para la función OR

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

tasa = 0.001
n_iterac = 10
estado_alea = 47
errors = []

# %%
# Este método calcula el valor para z basado en los pesos
def obtener_z(X):
    z = np.dot(X,w) + b
    return z

# %%
# Este método permite predecir la clase de una instancia (función escalón)
def predecir(X):
    z = obtener_z(X)
    if (z>=0.0):
        y = 1
    else:
        y = 0
    return y

# %%
# Este método aplica la regla de aprendizaje
def entrenar(X, y):
    # lista para almacenar los errores calculados
    global w,b
    for i in range(n_iterac):
        error = 0
        for xi, yi in zip(X, y):
            prediccion = predecir(xi)
            error = yi - prediccion
            if error != 0:
                actualizacion = tasa * error
                w +=  actualizacion * xi
                b +=  actualizacion
        errors.append(error)
    return w,b

# %%
# datos de la operación booleana or
X = np.array( [[1, 1],
              [0, 1],
              [1, 0],
              [0, 0]])
y = np.array([1, 1, 1, 0])

#inicializamos los pesos
w = np.zeros(X.shape[1])
#inicializamos el sesgo (bias)
b = np.float_(0)

# %%
entrenar(X,y)
w, b
# Out:
# (array([0.001, 0.001]), -0.001)

# %%
#prueba 1
prueba1 = np.array([1,0])
y = predecir(prueba1)
print("La predicción es:", y)
# Out:
# La predicción es: 1

# %%
plt.figure(figure=(4,3))
plt.plot(range(1, len(errors) + 1), errors, marker='o')
plt.rcParams['figure.dpi'] = 150
plt.xlabel('Época')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# ## Perceptrón para el dataset Iris

# %%
#importamos las librerias necesarios
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
# cargar el dataset iris
iris = load_iris()

# %%
# mostramos la primera instancia
iris.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
# mostramos el nombre de las clases de flores
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# mostramos el nombre de las variables descriptivas
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
# configuramos un dataframe de pandas
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df["tipo"] = iris.target
df.sample(5)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 93                5.0               2.3                3.3               1.0
# 62                6.0               2.2                4.0               1.0
# 23                5.1               3.3                1.7               0.5
# 78                6.0               2.9                4.5               1.5
# 88                5.6               3.0                4.1               1.3
#
#     tipo
# 93     1
# 62     1
# 23     0
# 78     1
# 88     1

# %%
# obtenemos X e y
X = df.iloc[0:100, [0,2] ]
y = df.iloc[0:100, 4]

# %%
# separar los datos en subconjunto de entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=0.2, random_state=47)

# %%
X_ent.shape, X_pru.shape, y_ent.shape, y_pru.shape
# Out:
# ((80, 2), (20, 2), (80,), (20,))

# %%
# dibujamos los puntos de datos
plt.figure(figsize=(4, 3))
plt.scatter(X.iloc[:50, 0], X.iloc[:50, 1],
            color='blue', marker='o', label='Setosa')
plt.scatter(X.iloc[50:100, 0], X.iloc[50:100, 1],
            color='green', marker='s', label='Versicolor')

plt.xlabel('Longitud del sépalo')
plt.ylabel('Logitud del pétalo')
plt.legend(loc='upper left')
plt.show()

# %%
from sklearn.linear_model import Perceptron
# se crea el objeto Perceptron max_iter(num épocas)=100  
perc = Perceptron(max_iter=100)
# entrenamos
perc.fit(X_ent, y_ent)
# Out:
# Perceptron(max_iter=100)

# %%
df_prueba = pd.DataFrame({'sepal length (cm)': [4], 'petal length (cm)': [5]})
y_pred = perc.predict(df_prueba)
if y_pred == 0:
    print("Setosa")
else:
    print("Versicolor")
# Out:
# Versicolor

# %%
#Generamos la matriz de confusión
from sklearn import metrics
# se calculan las predicciones de los datos de prueba
y_predicciones = perc.predict(X_pru)
print(metrics.confusion_matrix(y_true = y_pru, y_pred = y_predicciones))
# Out:
# [[ 9  0]
#  [ 0 11]]

# %%
#cálculamos la exactitud
print("Exactitud: {:.2f}".format( metrics.accuracy_score(y_true = y_pru,
      y_pred = y_predicciones)*100))
# Out:
# Exactitud: 100.00

# %%
def plot_decision_boundary(X, y, clf):
    x_min, x_max = X.iloc[:, 0].min() - 1, X.iloc[:, 0].max() + 1
    y_min, y_max = X.iloc[:, 1].min() - 1, X.iloc[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, alpha=0.8)
    plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y, marker='s', edgecolors='k')
  
# Dibujamos el límite de decisión
plt.figure(figsize=(4, 3))
plot_decision_boundary(X_pru, y_pru, perc)
plt.xlabel('Longitud del sépalo')
plt.ylabel('Longitud del pépalo')
#plt.title('Perceptrón en el dataset Iris (Clase Versicolor vs Setosa)')
plt.show()
# Out:
# C:\Users\Carlos Pineda\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #### ADALINE SOBRE DATASET IRIS

# %%
tasa=0.01
n_iterac=100

# %%
# Inicialización de pesos con valores pequeños aleatorios
w = np.random.rand(X.shape[1])
b = np.random.rand()

# %%
def entrenar(X, y):   
    global w,b
    for i in range(n_iterac):
        # Calcular la salida
        y_pred = obtener_z(X)
        # Calcular el error
        error = y - y_pred
        # Actualizar pesos y sesgo
        w += tasa * X.T.dot(error)
        b += tasa * error.sum()

# %%
def obtener_z(X):
    return np.dot(X, w) + b

# %%
def predecir(X):
    return np.where(obtener_z(X) >= 0.0, 1, -1)

# %%
entrenar(X_ent, y_ent)

# %%
prueba = np.array([[4 , 5]])
y_pred = predecir(prueba)
if y_pred == 0:
    print("La instancia corresponde a una flor: Setosa")
else:
    print("La instancia corresponde a una flor: Versicolor")
# Out:
# La instancia corresponde a una flor: Versicolor

# %%
#cálculamos la exactitud
# se calculan las predicciones de los datos de prueba
y_predicciones = perc.predict(X_pru)
print("Exactitud: {:.2f}".format( metrics.accuracy_score(y_true = y_pru,
      y_pred = y_predicciones)*100))
# Out:
# Exactitud: 100.00

# %% [markdown]
# #### BackPropagation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.datasets import load_iris
data = load_iris()
X = data['data'][:,0:2]  # Escogemos solo longitud del sepalo y ancho del sépalo
y = data['target']

# Escogemos solo las instancias etiquetadas como setosa (0) y versicolor (1)
X = X[y != 2]
y = y[y != 2].reshape(-1, 1)  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import numpy as np

# Función de activación (sigmoid)
def sigmoide(x):
    return 1 / (1 + np.exp(-x))

# Derivada de la función de activación
def derivada_sigmoide(x):
    return x * (1 - x)

num_entradas = 2
num_ocultas = 2
num_salidas = 1
W1 = np.random.randn(num_entradas, num_ocultas) * np.sqrt(2 / num_entradas)
W2 = np.random.randn(num_ocultas, num_salidas) * np.sqrt(2 / num_ocultas)
b1 = np.zeros((1, num_ocultas))
b2 = np.zeros((1, num_salidas))

X = X_train 
Y = y_train 
alpha = 0.01
num_iteraciones = 1000

for i in range(num_iteraciones):
    # Propagación hacia adelante
    Z1 = np.dot(X, W1) + b1
    A1 = sigmoide(Z1) #capa oculta
    Z2 = np.dot(A1, W2) + b2
    A2 = sigmoide(Z2) # capa de salida
                
    # Retropropagación Salida - Oculta
    d_C_a2 = Y - A2 # error
    d_a2_z2 = derivada_sigmoide(A2) # sigmoide prima
    d_C_z2 = d_C_a2 * d_a2_z2
    d_C_W2 = np.dot(A1.T, d_C_z2) # derivada del costo respecto a los pesos W2
    d_C_b2 = np.sum(d_C_z2, axis=0, keepdims=True)

    # Retropropagación Oculta - Entrada   
    #d_C_a1 = np.dot(d_C_z2.T, W2)
    d_a1_z1 = derivada_sigmoide(A1)
             
    d_C_W1 = np.dot(X.T, np.dot(d_C_z2, W2.T) * d_a1_z1)
    d_C_b1 = np.sum(np.dot(d_C_z2, W2.T) * d_a1_z1, axis=0, keepdims=True)
    
    # Actualización de pesos y sesgos
    W1 -= alpha * d_C_W1
    W2 -= alpha * d_C_W2
    b1 -= alpha * d_C_b1
    b2 -= alpha * d_C_b2

# %%
# Parámetros
print("Pesos de la capa oculta:\n", W1)
print("Sesgos de la capa oculta:\n", W2)
print("Pesos de la capa de salida:\n", b1)
print("Sesgos de la capa de salida:\n", b2)
# Out:
# Pesos de la capa oculta:
#  [[-4.86872602  2.36326845]
#  [ 3.05981837 -1.81513492]]
# Sesgos de la capa oculta:
#  [[ 8.97207583]
#  [-4.06928551]]
# Pesos de la capa de salida:
#  [[-1.06108128  0.36884381]]
# Sesgos de la capa de salida:
#  [[-2.44372669]]

# %%
def predict(X_prueba):
    Z1 = np.dot(X_prueba, W1) + b1
    A1 = sigmoide(Z1) #capa oculta
    Z2 = np.dot(A1, W2) + b2
    A2 = sigmoide(Z2) # capa de salida         
    return (A2 > 0.5).astype(int)

# %%
entrada = np.array([[4,5]])
entrada = scaler.transform(entrada)
p = predict(entrada)
if (p==0):
    print("La flor es de tipo setosa")
else: 
    print("La flor es de tipo versicolor")
# Out:
# La flor es de tipo versicolor

# %%
y_pred = predict(X_test)

# Evaluar el modelo
accuracy = np.mean(y_pred.flatten() == y_test)
print(f"Exactitud: {accuracy * 100:.1f}%")
# Out:
# Exactitud: 48.0%

# %%
# Dibujar la separación de los puntos linealmente
def plot_decision_boundary(X, y):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
                         np.arange(y_min, y_max, 0.01))
    Z = predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    plt.figure(figsize=(4, 3))
    plt.contourf(xx, yy, Z, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o')
    plt.xlabel('Característica 1')
    plt.ylabel('Característica 2')
    plt.title('Frontera de decisión')
    plt.show()

# Visualizar la frontera de decisión
plot_decision_boundary(X_train, y_train)

# %% [markdown]
# ### Red Neuronal para detectar la Deserción

# %%
import numpy as np
import pandas as pd
df = pd.read_excel('../datasets/datos_desercion.xlsx')

# %%
df.head(5)
# Out:
#    edad genero estado_civil  estrato  icfes  total_materias_perdidas  \
# 0    26      M      soltero        1    230                        7
# 1    30      M      soltero        1    139                        5
# 2    24      M      soltero        1    237                        3
# 3    22      M      soltero        2    236                        2
# 4    27      M      soltero        0    352                        8
#
#    cant_reingresos  ult_promedio_acad  acceso_plataforma_horas ¿deserta?
# 0              1.0                3.1                      0.5        si
# 1              2.0                2.5                      0.8        si
# 2              0.0                2.9                      0.0        si
# 3              0.0                4.1                      3.0        no
# 4              1.0                1.9                      0.0        si

# %%
df.isna().sum()
# Out:
# edad                       0
# genero                     0
# estado_civil               0
# estrato                    0
# icfes                      0
# total_materias_perdidas    0
# cant_reingresos            1
# ult_promedio_acad          0
# acceso_plataforma_horas    0
# ¿deserta?                  0
# dtype: int64

# %%
df['estado_civil'].value_counts()
# Out:
# estado_civil
# soltero        99
# Unión Libre     1
# Name: count, dtype: int64

# %%
#preprocesamiento
df.drop(columns=['estado_civil'], inplace=True)
df.fillna(value=df.cant_reingresos.mean(), inplace=True)

# %%
d1 = {'M': 1, 'F':0}
df['genero'] = df['genero'].map(d1)
d2 = {'si': 1, 'no':0}
df['¿deserta?'] = df['¿deserta?'].map(d2)

# %%
df
# Out:
#     edad  genero  estrato  icfes  total_materias_perdidas  cant_reingresos  \
# 0     26       1        1    230                        7              1.0
# 1     30       1        1    139                        5              2.0
# 2     24       1        1    237                        3              0.0
# 3     22       1        2    236                        2              0.0
# 4     27       1        0    352                        8              1.0
# ..   ...     ...      ...    ...                      ...              ...
# 95    23       1        1    190                        3              1.0
# 96    26       1        1    280                        1              1.0
# 97    20       1        1    224                        7              0.0
# 98    18       1        1    188                        8              0.0
# 99    27       1        3    330                        1              1.0
#
#     ult_promedio_acad  acceso_plataforma_horas  ¿deserta?
# 0                 3.1                      0.5          1
# 1                 2.5                      0.8          1
# 2                 2.9                      0.0          1
# 3                 4.1                      3.0          0
# 4                 1.9                      0.0          1
# ..                ...                      ...        ...
# 95                4.1                      1.0          0
# 96                3.7                      3.0          0
# 97                0.1                      1.0          1
# 98                2.0                      1.0          1
# 99                3.3                      5.0          0
#
# [100 rows x 9 columns]

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,8].values

from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
import seaborn as sb
import matplotlib.pyplot as pl
cm = np.corrcoef(df.values.T)
sb.set(rc = {'figure.figsize':(15,10)})
hm = sb.heatmap(cm, cbar=True,
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size':15},
                yticklabels=df.columns,
                xticklabels=df.columns
                )
pl.show(7,7)

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
modelo = Sequential()
modelo.add(Dense(units=500, activation='relu', input_shape=[8])), 
modelo.add(Dense(units=200, activation='relu'))
modelo.add(Dense(units=100, activation='relu'))
modelo.add(Dense(units=10, activation='relu'))
modelo.add(Dense(units=1, activation='sigmoid'))

# %%
modelo.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                     │ (None, 500)                 │           4,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 200)                 │         100,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 100)                 │          20,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 10)                  │           1,010 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 125,821 (491.49 KB)
#  Trainable params: 125,821 (491.49 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilamos  el modelo
modelo.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
historico = modelo.fit(X_ent, y_ent, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.3203 - loss: 4.4895
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6289 - loss: 7.6315
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4906 - loss: 2.9765
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4078 - loss: 1.1605
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6133 - loss: 1.0653
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5914 - loss: 0.7344
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4266 - loss: 0.7324
# Epoch 8/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6484 - loss: 0.6695
# Epoch 9/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6328 - loss: 0.6696
# Epoch 10/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7977 - loss: 0.5803
# Epoch 11/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6781 - loss: 0.5620
# Epoch 12/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5406 - loss: 0.6265
# Epoch 13/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6633 - loss: 0.6070
# Epoch 14/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7523 - loss: 0.5394
# Epoch 15/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7492 - loss: 0.5430
# Epoch 16/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4953 - loss: 0.7330
# Epoch 17/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6758 - loss: 0.5541
# Epoch 18/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7016 - loss: 0.6673
# Epoch 19/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4789 - loss: 1.0660
# Epoch 20/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6367 - loss: 0.8942
# Epoch 21/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6992 - loss: 0.6209
# Epoch 22/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7719 - loss: 0.6634
# Epoch 23/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6531 - loss: 0.5850
# Epoch 24/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8047 - loss: 0.4596
# Epoch 25/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7211 - loss: 0.4867
# Epoch 26/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8461 - loss: 0.3913
# Epoch 27/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.4145
# Epoch 28/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9031 - loss: 0.3446
# Epoch 29/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7250 - loss: 0
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9539 - loss: 0.0611

# %%
pred= modelo.predict(X_ent)
puntajes = modelo.evaluate(X_ent, y_ent, verbose=0)
print('Exactitud sobre datos de entrenamiento: {:.2f} \n Error sobre datos de entrenamiento: {:.2f}'.format(puntajes[1], 1 - puntajes[1]))

pred= modelo.predict(X_pru)
puntajes2 = modelo.evaluate(X_pru, y_pru, verbose=0)
print('Exactitud sobre datos de prueba: {:.2f} \n Error sobre datos de prueba: {:.2f}'.format(puntajes2[1], 1 - puntajes2[1]))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Exactitud sobre datos de entrenamiento: 0.98
#  Error sobre datos de entrenamiento: 0.02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Exactitud sobre datos de prueba: 0.90
#  Error sobre datos de prueba: 0.10

# %%
import pandas as pd
plt.rcParams['figure.dpi'] = 150
pd.DataFrame(historico.history).plot(figsize=(4,4))
# Out:
# <Axes: >

# %%
modelo.save("modelo.h5")

# %% [markdown]
# ### Red Neuronal para clasificar dígitos manuscritos

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.layers import Dense, Flatten

# %%
# cargamos los datos del módulo datasets de Keras
((X_ent, y_ent), (X_pru, y_pru)) = tf.keras.datasets.mnist.load_data()

# %%
# Normalizamos la imagenes
X_ent = X_ent/np.float32(255)
y_ent = y_ent.astype(np.int32)  
X_pru = X_pru/np.float32(255)
y_pru = y_pru.astype(np.int32)

# %%
modelo = tf.keras.Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128,  activation='relu'),
    Dense(10, activation='softmax')    
])
modelo.summary()
# Out:
# C:\Users\Carlos Pineda\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
history = modelo.fit(x=X_ent,y=y_ent, epochs=20, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/20
# C:\Users\Carlos Pineda\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\nn.py:635: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8639 - loss: 0.4789 - val_accuracy: 0.9512 - val_loss: 0.1681
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9595 - loss: 0.1382 - val_accuracy: 0.9637 - val_loss: 0.1228
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9730 - loss: 0.0915 - val_accuracy: 0.9689 - val_loss: 0.1001
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9800 - loss: 0.0659 - val_accuracy: 0.9703 - val_loss: 0.0979
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9868 - loss: 0.0472 - val_accuracy: 0.9741 - val_loss: 0.0856
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9882 - loss: 0.0386 - val_accuracy: 0.9736 - val_loss: 0.0892
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9912 - loss: 0.0295 - val_accuracy: 0.9754 - val_loss: 0.0833
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9934 - loss: 0.0240 - val_accuracy: 0.9772 - val_loss: 0.0840
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9948 - loss: 0.0189 - val_accuracy: 0.9758 - val_loss: 0.0928
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9956 - loss: 0.0152 - val_accuracy: 0.9764 - val_loss: 0.0896
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9970 - loss: 0.0116 - val_accuracy: 0.9742 - val_loss: 0.1055
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9961 - loss: 0.0124 - val_accuracy: 0.9767 - val_loss: 0.0962
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9975 - loss: 0.0076 - val_accuracy: 0.9771 - val_loss: 0.0950
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9978 - loss: 0.0074 - val_accuracy: 0.9761 - val_loss: 0.1060
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9980 - loss: 0.0073 - val_accuracy: 0.9749 - val_loss: 0.1165
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9977 - loss: 0.0075 - val_accuracy: 0.9775 - val_loss: 0.1015
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9986 - loss: 0.0051 - val_accuracy: 0.9750 - val_loss: 0.1228
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 0.9779 - val_loss: 0.1125
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9984 - loss: 0.0050 - val_accuracy: 0.9767 - val_loss: 0.1142
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9986 - loss: 0.0044 - val_accuracy: 0.9771 - val_loss: 0.1172

# %%
plt.rcParams['figure.dpi'] = 300
plt.plot(figsize=(4,4))
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoca')
plt.ylabel('Pérdida')
plt.legend()
plt.grid(True)

# %%
pred= modelo.predict(X_ent)
puntajes = modelo.evaluate(X_ent, y_ent, verbose=0)
print('Exactitud sobre datos de entrenamiento: {:.2f}'.format(puntajes[1]))

pred= modelo.predict(X_pru)
puntajes2 = modelo.evaluate(X_pru, y_pru, verbose=0)
print('Exactitud sobre datos de prueba: {:.2f}'.format(puntajes2[1]))
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Exactitud sobre datos de entrenamiento: 0.99
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Exactitud sobre datos de prueba: 0.98
